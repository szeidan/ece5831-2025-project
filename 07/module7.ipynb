# %% [markdown]
# # Module 7 – TwoLayerNet with Backprop (MNIST)
#
# This notebook shows training a two-layer network and testing on MNIST and your own digits.

# %%
# Train the network (this will save zeidan_mnist_model.pkl)
# !python train.py
# Out:
# epoch 1/5 | iter 00000 | loss 2.3027 | batch_acc 0.172
# epoch 1/5 | iter 00100 | loss 0.9519 | batch_acc 0.781
# epoch 1/5 | iter 00200 | loss 0.4568 | batch_acc 0.922
# epoch 1/5 | iter 00300 | loss 0.4400 | batch_acc 0.922
# epoch 1/5 | iter 00400 | loss 0.4086 | batch_acc 0.867
# [Epoch 1] Test accuracy: 0.9063
# epoch 2/5 | iter 00500 | loss 0.4456 | batch_acc 0.891
# epoch 2/5 | iter 00600 | loss 0.2995 | batch_acc 0.914
# epoch 2/5 | iter 00700 | loss 0.2998 | batch_acc 0.906
# epoch 2/5 | iter 00800 | loss 0.2912 | batch_acc 0.922
# epoch 2/5 | iter 00900 | loss 0.4082 | batch_acc 0.875
# [Epoch 2] Test accuracy: 0.9232
# epoch 3/5 | iter 01000 | loss 0.1673 | batch_acc 0.961
# epoch 3/5 | iter 01100 | loss 0.3056 | batch_acc 0.930
# epoch 3/5 | iter 01200 | loss 0.4132 | batch_acc 0.891
# epoch 3/5 | iter 01300 | loss 0.2140 | batch_acc 0.953
# epoch 3/5 | iter 01400 | loss 0.2789 | batch_acc 0.914
# [Epoch 3] Test accuracy: 0.9319
# ...

# %%
# Evaluate on MNIST test set
from module7 import evaluate_on_mnist_test
evaluate_on_mnist_test()
# Out:
# MNIST test accuracy: 0.9447
# 0.9447

# %% [markdown]
# ## Test it with your own handwritten digits
# Place a few digit images (PNG/JPG) in this working directory and list them below.
# Each should contain one digit, on a high-contrast background.

# %%
from pathlib import Path
from module7 import test_it_with_your_own_handwritten_digits

# Folder containing your test images
folder = Path("test_images")

# Build a sorted list of all images (assuming .png format)
image_paths = sorted(str(p) for p in folder.glob("*.png"))



# Run inference on all
test_it_with_your_own_handwritten_digits(image_paths)
# Out:
# test_images\0_0.png: predicted -> 0
# test_images\0_1.png: predicted -> 0
# test_images\0_2.png: predicted -> 0
# test_images\0_3.png: predicted -> 0
# test_images\0_4.png: predicted -> 0
# test_images\1_0.png: predicted -> 1
# test_images\1_1.png: predicted -> 1
# test_images\1_2.png: predicted -> 1
# test_images\1_3.png: predicted -> 1
# test_images\1_4.png: predicted -> 1
# test_images\2_0.png: predicted -> 2
# test_images\2_1.png: predicted -> 2
# test_images\2_2.png: predicted -> 2
# test_images\2_3.png: predicted -> 2
# test_images\2_4.png: predicted -> 2
# test_images\3_0.png: predicted -> 3
# test_images\3_1.png: predicted -> 3
# test_images\3_2.png: predicted -> 3
# test_images\3_3.png: predicted -> 3
# test_images\3_4.png: predicted -> 3
# test_images\4_0.png: predicted -> 4
# test_images\4_1.png: predicted -> 4
# test_images\4_2.png: predicted -> 9
# test_images\4_3.png: predicted -> 4
# test_images\4_4.png: predicted -> 4
# test_images\5_0.png: predicted -> 5
# ...
